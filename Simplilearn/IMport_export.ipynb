# %%
import pandas as pd

# %%
diabetes= pd.read_csv("diabetes.csv")
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
LungCap=pd.read_excel("LungCap.xlsx",usecols=[2,3,4,])
LungCap.head()
# Out:
#    Height(inches) Smoke  Gender
# 0            62.1    no    male
# 1            74.7   yes  female
# 2            69.7    no  female
# 3            71.0    no    male
# 4            56.9    no    male

# %%
Pulse =pd.read_excel("Pulse_Rate.xlsx")
Pulse.head(40)
# Out:
#     ID  Oxygen  PulseRate  Temperature    Result
# 0    0    98.0       65.0         95.0  Negative
# 1    1    96.0       92.0         95.0  Negative
# 2    2    95.0       92.0         99.0  Negative
# 3    3    97.0       56.0         96.0  Negative
# 4    4    88.0       94.0         98.0  Positive
# 5    5    94.0      100.0        103.0  Positive
# 6    6    88.0       81.0        104.0  Positive
# 7    7    91.0       79.0         95.0  Negative
# 8    8    93.0       59.0        101.0  Positive
# 9    9    86.0      117.0         99.0  Positive
# 10  10    94.0       75.0         95.0  Negative
# 11  11    98.0       46.0         96.0  Negative
# 12  12    86.0       85.0         98.0  Positive
# 13  13    90.0       55.0        101.0  Positive
# 14  14    93.0       67.0         97.0  Negative
# 15  15    89.0       66.0         97.0  Positive
# 16  16    89.0      121.0         99.0  Positive
# 17  17    94.0      111.0         96.0  Negative
# ...

# %%
Pulse =pd.read_excel("Pulse_Rate.xlsx",index_col=0,header=0,usecols=["ID","Oxygen","PulseRate","Result"])
Pulse.head(40)
# Out:
#     Oxygen  PulseRate    Result
# ID
# 0     98.0       65.0  Negative
# 1     96.0       92.0  Negative
# 2     95.0       92.0  Negative
# 3     97.0       56.0  Negative
# 4     88.0       94.0  Positive
# 5     94.0      100.0  Positive
# 6     88.0       81.0  Positive
# 7     91.0       79.0  Negative
# 8     93.0       59.0  Positive
# 9     86.0      117.0  Positive
# 10    94.0       75.0  Negative
# 11    98.0       46.0  Negative
# 12    86.0       85.0  Positive
# 13    90.0       55.0  Positive
# 14    93.0       67.0  Negative
# 15    89.0       66.0  Positive
# 16    89.0      121.0  Positive
# 17    94.0      111.0  Negative
# 18    97.0      120.0  Negative
# 19    93.0      108.0  Positive
# 20    96.0      114.0  Negative
# 21    97.0       48.0  Negative
# 22    95.0      117.0  Negative
# 23    93.0       51.0  Positive
# 24    99.0       49.0  Negative
# 25    96.0      123.0  Negative
# 26    97.0      124.0  Negative
# 27    94.0       55.0  Negative
# ...

# %%
cols_name=["A","B","c","D","E","F","G","H","I"]
diabetes= pd.read_csv("diabetes.csv",delimiter="\t",header=None, names=cols_name)
diabetes.head()
# Out:
#                                                    A   B   c   D   E   F   G  \
# 0  Pregnancies,Glucose,BloodPressure,SkinThicknes... NaN NaN NaN NaN NaN NaN
# 1                      6,148,72,35,0,33.6,0.627,50,1 NaN NaN NaN NaN NaN NaN
# 2                       1,85,66,29,0,26.6,0.351,31,0 NaN NaN NaN NaN NaN NaN
# 3                       8,183,64,0,0,23.3,0.672,32,1 NaN NaN NaN NaN NaN NaN
# 4                      1,89,66,23,94,28.1,0.167,21,0 NaN NaN NaN NaN NaN NaN
#
#     H   I
# 0 NaN NaN
# 1 NaN NaN
# 2 NaN NaN
# 3 NaN NaN
# 4 NaN NaN

# %%
Covide=pd.read_csv("Covid_19_data.csv",index_col="State")
Covide.head()
# Out:
#               Start Date   End Date     Group  Year  Month  \
# State
# United States   1/1/2020  9/23/2023  By Total   NaN    NaN
# United States   1/1/2020  9/23/2023  By Total   NaN    NaN
# United States   1/1/2020  9/23/2023  By Total   NaN    NaN
# United States   1/1/2020  9/23/2023  By Total   NaN    NaN
# United States   1/1/2020  9/23/2023  By Total   NaN    NaN
#
#                     Condition Group                Condition ICD10_codes  \
# State
# United States  Respiratory diseases  Influenza and pneumonia     J09-J18
# United States  Respiratory diseases  Influenza and pneumonia     J09-J18
# United States  Respiratory diseases  Influenza and pneumonia     J09-J18
# United States  Respiratory diseases  Influenza and pneumonia     J09-J18
# United States  Respiratory diseases  Influenza and pneumonia     J09-J18
#
#               Age Group  COVID-19 Deaths  Number of Mentions Flag
# State
# United States      0-24           1569.0              1647.0  NaN
# ...

# %%
Covide=pd.read_csv("Covid_19_data.csv")
Covide.head()
drop=Covide.dropna()

# %%
Covide=pd.read_csv("Covid_19_data.csv",usecols=[4,5])
Covide.head(1000)
drop=Covide.dropna()
drop
# Out:
#         Month          State
# 62100     1.0  United States
# 62101     2.0  United States
# 62102     3.0  United States
# 62103     4.0  United States
# 62104     5.0  United States
# ...       ...            ...
# 620995    5.0    Puerto Rico
# 620996    6.0    Puerto Rico
# 620997    7.0    Puerto Rico
# 620998    8.0    Puerto Rico
# 620999    9.0    Puerto Rico
#
# [558900 rows x 2 columns]

# %%
URL= "https://en.wikipedia.org/wiki/1976_Summer_Olympics_medal_table"

# %%
df=pd.read_html(URL)
df
# Out:
# [               1976 Summer Olympics medals  \
#  0                                 Location
#  1                               Highlights
#  2                         Most gold medals
#  3                        Most total medals
#  4  ← 1972 · Olympics medal tables · 1980 →
#  5                                 ← 1972 ·
#
#               1976 Summer Olympics medals.1 Unnamed: 2
#  0                         Montreal, Canada        NaN
#  1                               Highlights        NaN
#  2                        Soviet Union (49)        NaN
#  3                       Soviet Union (125)        NaN
#  4  ← 1972 · Olympics medal tables · 1980 →        NaN
#  5                    Olympics medal tables   · 1980 →  ,
#            0                      1         2
#  0  ← 1972 ·  Olympics medal tables  · 1980 →,
#                                                     0
#  0                                Part of a series on
#  1                               1976 Summer Olympics
# ...

# %%
type(df)
# Out:
# list

# %%
df= pd.read_html(URL)[0]
df.head(20)
# Out:
#                1976 Summer Olympics medals  \
# 0                                 Location
# 1                               Highlights
# 2                         Most gold medals
# 3                        Most total medals
# 4  ← 1972 · Olympics medal tables · 1980 →
# 5                                 ← 1972 ·
#
#              1976 Summer Olympics medals.1 Unnamed: 2
# 0                         Montreal, Canada        NaN
# 1                               Highlights        NaN
# 2                        Soviet Union (49)        NaN
# 3                       Soviet Union (125)        NaN
# 4  ← 1972 · Olympics medal tables · 1980 →        NaN
# 5                    Olympics medal tables   · 1980 →
